# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidChen20226/Data-Analysis---Covid-19-analysis/blob/main/covid_lockdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing numpy, pandas, seaborn, matplotlib

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the csv file

# %%
df = pd.read_csv('COVID-19 Survey Student Responses.csv')

# %%
df.head()
# Out:
#    ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0  R1           Delhi-NCR              21                         2.0
# 1  R2           Delhi-NCR              21                         0.0
# 2  R3           Delhi-NCR              20                         7.0
# 3  R4           Delhi-NCR              20                         3.0
# 4  R5           Delhi-NCR              21                         3.0
#
#   Rating of Online Class experience Medium for online class  \
# 0                              Good          Laptop/Desktop
# 1                         Excellent              Smartphone
# 2                         Very poor          Laptop/Desktop
# 3                         Very poor              Smartphone
# 4                              Good          Laptop/Desktop
#
#    Time spent on self study  Time spent on fitness  Time spent on sleep  \
# 0                       4.0                    0.0                  7.0
# ...

# %% [markdown]
# showing the category types

# %%
df["ID"] = df["ID"].astype('category')
print(df.dtypes)
# Out:
# ID                                                                                    category
# Region of residence                                                                     object
# Age of Subject                                                                           int64
# Time spent on Online Class                                                             float64
# Rating of Online Class experience                                                       object
# Medium for online class                                                                 object
# Time spent on self study                                                               float64
# Time spent on fitness                                                                  float64
# Time spent on sleep                                                                    float64
# Time spent on social media                                                             float64
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Turning object to float and replacing text

# %%
df['Time spent on TV'].replace('No tv', 0, inplace=True)
df['Time spent on TV'].replace('n', 0, inplace=True)
df['Time spent on TV'].replace('N', 0, inplace=True)
df['Time spent on TV'].replace(' ', 0, inplace=True)
df['Time spent on TV'] = df['Time spent on TV'].astype('float')
df['Prefered social media platform'] = df['Prefered social media platform'].replace('None ', 'None')
df['Prefered social media platform'] = df['Prefered social media platform'].replace('Whatsapp', 'WhatsApp')

# %% [markdown]
# converting floats to integers

# %%
# Assuming df is your DataFrame
df['Time spent on Online Class'] = df['Time spent on Online Class'].round().astype(int)
df['Time spent on self study'] = df['Time spent on self study'].round().astype(int)
df['Time spent on fitness'] = df['Time spent on fitness'].round().astype(int)
df['Time spent on sleep'] = df['Time spent on sleep'].round().astype(int)
df['Time spent on social media'] = df['Time spent on social media'].round().astype(int)

df['Time spent on TV'] = pd.to_numeric(df['Time spent on TV'], errors='coerce').astype('int')

display(df)
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                           2
# 1        R2           Delhi-NCR              21                           0
# 2        R3           Delhi-NCR              20                           7
# 3        R4           Delhi-NCR              20                           3
# 4        R5           Delhi-NCR              21                           3
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                           3
# 1178  R1192           Delhi-NCR              14                           6
# 1179  R1193           Delhi-NCR              13                           4
# 1180  R1194           Delhi-NCR              14                           5
# 1181  R1195           Delhi-NCR              13                           5
#
# ...

# %% [markdown]
# converting floats to integers

# %%
import pandas as pd

# Assuming df is your DataFrame
df['Time spent on Online Class'] = df['Time spent on Online Class'].round().astype(int)
df['Time spent on self study'] = df['Time spent on self study'].round().astype(int)
df['Time spent on fitness'] = df['Time spent on fitness'].round().astype(int)
df['Time spent on sleep'] = df['Time spent on sleep'].round().astype(int)
df['Time spent on social media'] = df['Time spent on social media'].round().astype(int)
df['Time spent on TV'] = df['Time spent on TV'].round().astype(int)
#df['Time spent on TV'] = pd.to_numeric(df['Time spent on TV'], errors='coerce').astype('int')

display(df)
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                           2
# 1        R2           Delhi-NCR              21                           0
# 2        R3           Delhi-NCR              20                           7
# 3        R4           Delhi-NCR              20                           3
# 4        R5           Delhi-NCR              21                           3
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                           3
# 1178  R1192           Delhi-NCR              14                           6
# 1179  R1193           Delhi-NCR              13                           4
# 1180  R1194           Delhi-NCR              14                           5
# 1181  R1195           Delhi-NCR              13                           5
#
# ...

# %%
df['Rating of Online Class experience'] = df['Rating of Online Class experience'].astype(str)
df['Region of residence'] = df['Region of residence'].astype(str)
df['Medium for online class'] = df['Medium for online class'].astype(str)
display(df)
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                           2
# 1        R2           Delhi-NCR              21                           0
# 2        R3           Delhi-NCR              20                           7
# 3        R4           Delhi-NCR              20                           3
# 4        R5           Delhi-NCR              21                           3
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                           3
# 1178  R1192           Delhi-NCR              14                           6
# 1179  R1193           Delhi-NCR              13                           4
# 1180  R1194           Delhi-NCR              14                           5
# 1181  R1195           Delhi-NCR              13                           5
#
# ...

# %%
df.head()
# Out:
#    ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0  R1           Delhi-NCR              21                           2
# 1  R2           Delhi-NCR              21                           0
# 2  R3           Delhi-NCR              20                           7
# 3  R4           Delhi-NCR              20                           3
# 4  R5           Delhi-NCR              21                           3
#
#   Rating of Online Class experience Medium for online class  \
# 0                              Good          Laptop/Desktop
# 1                         Excellent              Smartphone
# 2                         Very poor          Laptop/Desktop
# 3                         Very poor              Smartphone
# 4                              Good          Laptop/Desktop
#
#    Time spent on self study  Time spent on fitness  Time spent on sleep  \
# 0                         4                      0                    7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 19 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   ID                                                                                  1182 non-null   category
#  1   Region of residence                                                                 1182 non-null   object
#  2   Age of Subject                                                                      1182 non-null   int64
#  3   Time spent on Online Class                                                          1182 non-null   int64
#  4   Rating of Online Class experience                                                   1182 non-null   object
# ...

# %%
df.describe()
# Out:
#        Age of Subject  Time spent on Online Class  Time spent on self study  \
# count     1182.000000                 1182.000000               1182.000000
# mean        20.165821                    3.209814                  2.907783
# std          5.516467                    2.107196                  2.144435
# min          7.000000                    0.000000                  0.000000
# 25%         17.000000                    2.000000                  2.000000
# 50%         20.000000                    3.000000                  2.000000
# 75%         21.000000                    5.000000                  4.000000
# max         59.000000                   10.000000                 18.000000
#
#        Time spent on fitness  Time spent on sleep  Time spent on social media  \
# count            1182.000000          1182.000000                 1182.000000
# mean                0.741117             7.871404                    2.356176
# ...

# %%
nan_count = df.isna().sum()

print(nan_count)
# Out:
# ID                                                                                    0
# Region of residence                                                                   0
# Age of Subject                                                                        0
# Time spent on Online Class                                                            0
# Rating of Online Class experience                                                     0
# Medium for online class                                                               0
# Time spent on self study                                                              0
# Time spent on fitness                                                                 0
# Time spent on sleep                                                                   0
# Time spent on social media                                                            0
# Prefered social media platform                                                        0
# ...

# %%
print("The number of people use Instagram")
#Counting the number of rows where the 'Prefered social media platform' column has the value 'Instagram.'
df[df['Prefered social media platform']=='Instagram'].count()
# Out:
# The number of people use Instagram
# ID                                                                                    352
# Region of residence                                                                   352
# Age of Subject                                                                        352
# Time spent on Online Class                                                            352
# Rating of Online Class experience                                                     352
# Medium for online class                                                               352
# Time spent on self study                                                              352
# Time spent on fitness                                                                 352
# Time spent on sleep                                                                   352
# Time spent on social media                                                            352
# ...

# %%
print("The number of people use Linkedin")
#Counting the number of rows where the 'Prefered social media platform' column has the value 'Linkedin'
df[df['Prefered social media platform']=='Linkedin'].count()
# Out:
# The number of people use Linkedin
# ID                                                                                    61
# Region of residence                                                                   61
# Age of Subject                                                                        61
# Time spent on Online Class                                                            61
# Rating of Online Class experience                                                     61
# Medium for online class                                                               61
# Time spent on self study                                                              61
# Time spent on fitness                                                                 61
# Time spent on sleep                                                                   61
# Time spent on social media                                                            61
# ...

# %%
print("The number of people use Laptop/Desktop for online classes")
#Counting the number of rows where the 'medium for online class' column has the value 'Laptop/Desktop'
df[df['Medium for online class'] == 'Laptop/Desktop'].info()
# Out:
# The number of people use Laptop/Desktop for online classes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 545 entries, 0 to 1180
# Data columns (total 19 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   ID                                                                                  545 non-null    object
#  1   Region of residence                                                                 545 non-null    object
#  2   Age of Subject                                                                      545 non-null    int64
#  3   Time spent on Online Class                                                          545 non-null    float64
#  4   Rating of Online Class experience                                                   545 non-null    object
# ...

# %%
column_data = df['Medium for online class']
display(column_data)
# Out:
# 0       Laptop/Desktop
# 1           Smartphone
# 2       Laptop/Desktop
# 3           Smartphone
# 4       Laptop/Desktop
#              ...
# 1177        Smartphone
# 1178        Smartphone
# 1179        Smartphone
# 1180    Laptop/Desktop
# 1181            Tablet
# Name: Medium for online class, Length: 1182, dtype: object

# %%
sns.countplot(x='Medium for online class', data=df,)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
df['Age of Subject'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(x = 'Rating of Online Class experience', y = 'Age of Subject', data = df)
# Out:
# <Axes: xlabel='Rating of Online Class experience', ylabel='Age of Subject'>

# %% [markdown]
# what do students miss the most

# %%
plt.figure(figsize=(12,8))
sns.set(style='darkgrid')
sns.countplot(y='What you miss the most', data=df, order=df['What you miss the most'].value_counts().index[:10], palette='Set3')
plt.xlabel("Number of Subjects", weight='bold')
plt.ylabel("What did they miss?", weight='bold')
plt.show()

# %% [markdown]
# How they use their time

# %%
sns.set(style='darkgrid')
fig, ax = plt.subplots(3,2, figsize=(16,18))
sns.boxplot(x='Time utilized', y='Time spent on Online Class', data=df, ax=ax[0,0])
sns.boxplot(x='Time utilized', y='Time spent on self study', data=df, ax=ax[0,1])
sns.boxplot(x='Time utilized', y='Time spent on fitness', data=df, ax=ax[1,0])
sns.boxplot(x='Time utilized', y='Time spent on sleep', data=df, ax=ax[1,1])
sns.boxplot(x='Time utilized', y='Time spent on social media', data=df, ax=ax[2,0])
sns.boxplot(x='Time utilized', y='Time spent on TV', data=df, ax=ax[2,1])
plt.show()
